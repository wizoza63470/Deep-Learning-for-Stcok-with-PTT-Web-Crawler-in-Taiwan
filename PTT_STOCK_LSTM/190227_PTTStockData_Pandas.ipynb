# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
import codecs 

with codecs.open('Stock-100-200.json', 'r', 'utf-8') as data_file:
  data_teacher = json.load(data_file)

# %%
df = pd.DataFrame.from_dict(data_teacher)

# %%
df2 = pd.DataFrame(data_teacher, columns = list('ABC'))

# %%
df.shape
# Out:
# (2019, 1)

# %%
df3 = list()
for n in data_teacher.items():
    for i in n:
        df3.append(i)

# %%
df3.remove(df3[0])

# %%
df30 = df3[0]

# %%
df = pd.DataFrame.from_dict(df3[0], orient='columns')

# %%
df.to_csv('Stock-100-200.csv')

# %%
Stock = df.loc[:,'article_title':'content']
Stock
# Out:
#                             article_title                              author  \
# 0                     [新聞] 台股殺！ 5000億銀彈待命                     cobepupu (摳比撲撲)
# 1                     [新聞] 需求升 南亞3月營收月增7%                 fish19831012 (fish)
# 2     [新聞]國精化學 2013年3月合併營收4.59億元 年增-3.94%                     AlexKuo (修身養性中)
# 3                 [新聞]主計總處預估值腰斬！第一季出口年增率只         ilqgray (徵求ladygaga的票兩張 3Q)
# 4                          [標的] 1730 8088                       ha116900 (阿鴻)
# 5                            [標的] 2618長榮航             eejimchan (我那美得不能再美的人生)
# 6                      [請益] 是該收手還是該貪婪的時候?                        ciaerin (^^)
# 7                     [新聞] 日圓貶破99大關 4年來首見                     unioly (unioly)
# 8                        [其他] 看盤軟體 一銀vs元大                  chronodl (我是市井小小民)
# 9                 [新聞]雲、端業務各自專注發展，神達將轉型為꜠                         chiy16 (zz)
# 10                    [新聞] 宏達電獲利創低 法人：優預期  Huntelaar (Klaas Jan Huntelaar !!)
# ...

# %%
mask = Stock['article_title'].str.startswith("[標的]", na = False)
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25      False
# 26       True
# 27      False
# 28      False
# 29       True
#         ...
# 1989    False
# 1990     True
# 1991    False
# 1992    False
# 1993     True
# 1994     True
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# 2000     True
# 2001    False
# 2002    False
# 2003    False
# 2004    False
# 2005    False
# 2006    False
# 2007    False
# 2008    False
# 2009    False
# 2010    False
# 2011    False
# 2012    False
# 2013    False
# 2014    False
# 2015     True
# 2016    False
# 2017    False
# 2018    False
# ...

# %%
Stockb =  Stock[mask]

# %%
Stockb = Stockb.loc[:,('article_title', 'content')]

# %%
mask2 = Stockb['article_title'].str.contains("多" or "空", na = False)
Stockb[mask2]
# Out:
#                         article_title  \
# 56                       [標的] 2303(多)
# 58                       [標的] 2498(多)
# 66    [標的] 9946 三發 3月年增10310.52%是利多嗎？
# 77                   [標的] 2420 新巨 (多)
# 188                [標的] 戰神艾佛森談2498(多)
# 628                     [標的] 2382廣達 多
# 949           [標的] 1476 169~166回補後作多單
# 961                      [標的] 新纖 用力做多
# 1077                      [標的] 2317 多
# 1263                   [標的] 1558 伸興 多
# 1599                         [標的] 介面多
#
#                                                 content
# 56    1. 標的：2303 2. 進場理由 a.基本面：不怎樣 b.技術面：空頭排列 c.籌碼面：...
# 58    1. 標的：2498 2. 進場理由 a.基本面：Q1落底 多頭弟兄準備大反攻 b.技術面：...
# 66    三發(9946)是營建業 近年的整體財報已經挺不錯了 今天公布3月營收，年增率超過一萬% 看...
# 77    1. 標的：新巨 2420 2. 進場理由 a.基本面：持續擴充產線 雲端伺服器用power...
# 188   : 1. 標的：2498 : 2. 進場理由 : a.基本面：Q1落底 多頭弟兄準備大反攻 ...
# 628   1. 標的：廣達 2. 進場理由 a.基本面：獲利沒有利空 b.技術面：站穩 c.籌碼面：外...
# 949   1. 標的：1476 2. 進場理由 a.基本面：可以 b.技術面： 169短線回補 多單至...
# ...
